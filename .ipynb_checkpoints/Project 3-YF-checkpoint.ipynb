# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#dowload all the company as list
ticker = ["AMZN", "GOOGL", "MCD", "VZ", "BAC",]

# %%
#assign start date and end date
stocks = yf.download(ticker, start = "2014-01-01", end = "2023-11-24")
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %%
stocks.head()
# Out:
#             Adj Close                                                  Close  \
#                  AMZN        BAC      GOOGL        MCD         VZ       AMZN
# Date
# 2014-01-02  19.898500  13.307185  27.855856  74.020378  30.258951  19.898500
# 2014-01-03  19.822001  13.563411  27.652653  74.120186  29.900784  19.822001
# 2014-01-06  19.681499  13.770041  27.960960  73.590424  30.067526  19.681499
# 2014-01-07  19.901501  13.637794  28.500000  73.997337  30.444227  19.901501
# 2014-01-08  20.096001  13.703918  28.559309  73.252602  30.275677  20.096001
#
#                                                     ...       Open             \
#               BAC      GOOGL        MCD         VZ  ...       AMZN        BAC
# Date                                                ...
# 2014-01-02  16.10  27.855856  96.410004  49.000000  ...  19.940001  15.690000
# 2014-01-03  16.41  27.652653  96.540001  48.419998  ...  19.914499  16.270000
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                                                \
#                   AMZN        BAC       GOOGL         MCD         VZ
# Date
# 2023-11-16  142.830002  29.306097  136.929993  274.475372  36.180000
# 2023-11-17  145.179993  29.742613  135.309998  274.107574  36.230000
# 2023-11-20  146.130005  29.772375  136.250000  277.368042  36.730000
# 2023-11-21  143.899994  29.425146  136.970001  278.799469  37.250000
# 2023-11-22  146.710007  29.395384  138.490005  280.250763  37.349998
#
#                  Close                                                ...  \
#                   AMZN        BAC       GOOGL         MCD         VZ  ...
# Date                                                                  ...
# 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000  ...
# 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000  ...
# 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000  ...
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2491 entries, 2014-01-02 to 2023-11-22
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, AMZN)   2491 non-null   float64
#  1   (Adj Close, BAC)    2491 non-null   float64
#  2   (Adj Close, GOOGL)  2491 non-null   float64
#  3   (Adj Close, MCD)    2491 non-null   float64
#  4   (Adj Close, VZ)     2491 non-null   float64
#  5   (Close, AMZN)       2491 non-null   float64
#  6   (Close, BAC)        2491 non-null   float64
#  7   (Close, GOOGL)      2491 non-null   float64
#  8   (Close, MCD)        2491 non-null   float64
#  9   (Close, VZ)         2491 non-null   float64
#  10  (High, AMZN)        2491 non-null   float64
#  11  (High, BAC)         2491 non-null   float64
#  12  (High, GOOGL)       2491 non-null   float64
#  13  (High, MCD)         2491 non-null   float64
#  14  (High, VZ)          2491 non-null   float64
# ...

# %%
#export the initial dataset
stocks.to_csv("stocksYF.csv")

# %%
stocks = pd.read_csv("stocksYF.csv")
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AMZN                 BAC               GOOGL
# 1           Date                 NaN                 NaN                 NaN
# 2     2014-01-02  19.898500442504883  13.307185173034668   27.85585594177246
# 3     2014-01-03   19.82200050354004  13.563410758972168  27.652652740478516
# 4     2014-01-06  19.681499481201172  13.770041465759277  27.960960388183594
# ...          ...                 ...                 ...                 ...
# 2488  2023-11-16   142.8300018310547   29.30609703063965  136.92999267578125
# 2489  2023-11-17  145.17999267578125  29.742612838745117  135.30999755859375
# 2490  2023-11-20   146.1300048828125  29.772375106811523              136.25
# 2491  2023-11-21  143.89999389648438  29.425146102905273  136.97000122070312
# 2492  2023-11-22   146.7100067138672  29.395383834838867  138.49000549316406
#
# ...

# %%
#correct the date column and header
stocks = pd.read_csv("stocksYF.csv", header = [0,1], index_col = [0], parse_dates = [0])
stocks
# Out:
#              Adj Close                                                \
#                   AMZN        BAC       GOOGL         MCD         VZ
# Date
# 2014-01-02   19.898500  13.307185   27.855856   74.020378  30.258951
# 2014-01-03   19.822001  13.563411   27.652653   74.120186  29.900784
# 2014-01-06   19.681499  13.770041   27.960960   73.590424  30.067526
# 2014-01-07   19.901501  13.637794   28.500000   73.997337  30.444227
# 2014-01-08   20.096001  13.703918   28.559309   73.252602  30.275677
# ...                ...        ...         ...         ...        ...
# 2023-11-16  142.830002  29.306097  136.929993  274.475372  36.180000
# 2023-11-17  145.179993  29.742613  135.309998  274.107574  36.230000
# 2023-11-20  146.130005  29.772375  136.250000  277.368042  36.730000
# 2023-11-21  143.899994  29.425146  136.970001  278.799469  37.250000
# 2023-11-22  146.710007  29.395384  138.490005  280.250763  37.349998
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AMZN'),
#             ('Adj Close',   'BAC'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',   'MCD'),
#             ('Adj Close',    'VZ'),
#             (    'Close',  'AMZN'),
#             (    'Close',   'BAC'),
#             (    'Close', 'GOOGL'),
#             (    'Close',   'MCD'),
#             (    'Close',    'VZ'),
#             (     'High',  'AMZN'),
#             (     'High',   'BAC'),
#             (     'High', 'GOOGL'),
#             (     'High',   'MCD'),
#             (     'High',    'VZ'),
#             (      'Low',  'AMZN'),
#             (      'Low',   'BAC'),
#             (      'Low', 'GOOGL'),
#             (      'Low',   'MCD'),
#             (      'Low',    'VZ'),
#             (     'Open',  'AMZN'),
#             (     'Open',   'BAC'),
#             (     'Open', 'GOOGL'),
#             (     'Open',   'MCD'),
#             (     'Open',    'VZ'),
#             (   'Volume',  'AMZN'),
# ...

# %%
# convert a multi-level column index into a flat index
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([ ('Adj Close', 'AMZN'),   ('Adj Close', 'BAC'), ('Adj Close', 'GOOGL'),
#          ('Adj Close', 'MCD'),    ('Adj Close', 'VZ'),      ('Close', 'AMZN'),
#              ('Close', 'BAC'),     ('Close', 'GOOGL'),       ('Close', 'MCD'),
#               ('Close', 'VZ'),       ('High', 'AMZN'),        ('High', 'BAC'),
#             ('High', 'GOOGL'),        ('High', 'MCD'),         ('High', 'VZ'),
#               ('Low', 'AMZN'),         ('Low', 'BAC'),       ('Low', 'GOOGL'),
#                ('Low', 'MCD'),          ('Low', 'VZ'),       ('Open', 'AMZN'),
#               ('Open', 'BAC'),      ('Open', 'GOOGL'),        ('Open', 'MCD'),
#                ('Open', 'VZ'),     ('Volume', 'AMZN'),      ('Volume', 'BAC'),
#           ('Volume', 'GOOGL'),      ('Volume', 'MCD'),       ('Volume', 'VZ')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AMZN)  (Adj Close, BAC)  (Adj Close, GOOGL)  \
# Date
# 2014-01-02          19.898500         13.307185           27.855856
# 2014-01-03          19.822001         13.563411           27.652653
# 2014-01-06          19.681499         13.770041           27.960960
# 2014-01-07          19.901501         13.637794           28.500000
# 2014-01-08          20.096001         13.703918           28.559309
# ...                       ...               ...                 ...
# 2023-11-16         142.830002         29.306097          136.929993
# 2023-11-17         145.179993         29.742613          135.309998
# 2023-11-20         146.130005         29.772375          136.250000
# 2023-11-21         143.899994         29.425146          136.970001
# 2023-11-22         146.710007         29.395384          138.490005
#
#             (Adj Close, MCD)  (Adj Close, VZ)  (Close, AMZN)  (Close, BAC)  \
# Date
# ...

# %%
# convert mult index to one tuple
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                                                \
#                   AMZN        BAC       GOOGL         MCD         VZ
# Date
# 2014-01-02   19.898500  13.307185   27.855856   74.020378  30.258951
# 2014-01-03   19.822001  13.563411   27.652653   74.120186  29.900784
# 2014-01-06   19.681499  13.770041   27.960960   73.590424  30.067526
# 2014-01-07   19.901501  13.637794   28.500000   73.997337  30.444227
# 2014-01-08   20.096001  13.703918   28.559309   73.252602  30.275677
# ...                ...        ...         ...         ...        ...
# 2023-11-16  142.830002  29.306097  136.929993  274.475372  36.180000
# 2023-11-17  145.179993  29.742613  135.309998  274.107574  36.230000
# 2023-11-20  146.130005  29.772375  136.250000  277.368042  36.730000
# 2023-11-21  143.899994  29.425146  136.970001  278.799469  37.250000
# 2023-11-22  146.710007  29.395384  138.490005  280.250763  37.349998
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close',  'AMZN'),
#             ('Adj Close',   'BAC'),
#             ('Adj Close', 'GOOGL'),
#             ('Adj Close',   'MCD'),
#             ('Adj Close',    'VZ'),
#             (    'Close',  'AMZN'),
#             (    'Close',   'BAC'),
#             (    'Close', 'GOOGL'),
#             (    'Close',   'MCD'),
#             (    'Close',    'VZ'),
#             (     'High',  'AMZN'),
#             (     'High',   'BAC'),
#             (     'High', 'GOOGL'),
#             (     'High',   'MCD'),
#             (     'High',    'VZ'),
#             (      'Low',  'AMZN'),
#             (      'Low',   'BAC'),
#             (      'Low', 'GOOGL'),
#             (      'Low',   'MCD'),
#             (      'Low',    'VZ'),
#             (     'Open',  'AMZN'),
#             (     'Open',   'BAC'),
#             (     'Open', 'GOOGL'),
#             (     'Open',   'MCD'),
#             (     'Open',    'VZ'),
#             (   'Volume',  'AMZN'),
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AMZN          BAC        GOOGL          MCD           VZ
# count  2491.000000  2491.000000  2491.000000  2491.000000  2491.000000
# mean     83.755831    24.057753    68.486539   162.344571    39.269664
# std      51.240876     8.867238    36.201975    66.201094     6.760886
# min      14.347500     9.404630    24.853001    70.258980    28.613152
# 25%      36.121750    14.414871    38.413500    99.496155    33.234680
# 50%      86.189499    24.780365    56.964001   156.660385    37.172352
# 75%     125.645500    29.569080    97.779999   219.952675    46.198879
# max     186.570496    46.799240   149.838501   295.046356    52.166168
#
#              Close                                                      ...  \
#               AMZN          BAC        GOOGL          MCD           VZ  ...
# count  2491.000000  2491.000000  2491.000000  2491.000000  2491.000000  ...
# ...

# %%
#use close price only for Project 3 only 
close = stocks.loc[:,"Close"]
close
# Out:
#                   AMZN        BAC       GOOGL         MCD         VZ
# Date
# 2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...                ...        ...         ...         ...        ...
# 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
# [2491 rows x 5 columns]

# %%
#export the close price as new dataset
close.to_csv("stocksClose.csv")

# %%
close = pd.read_csv('stocksClose.csv', parse_dates=['Date'])
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
# [2491 rows x 6 columns]

# %%
print(close.columns)
# Out:
# Index(['Date', 'AMZN', 'BAC', 'GOOGL', 'MCD', 'VZ'], dtype='object')

# %%
#add a new column to show "Date" column as Quarter
close['Quarter'] = close['Date'].dt.to_period('Q')
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Quarter
# 0     2014Q1
# 1     2014Q1
# 2     2014Q1
# 3     2014Q1
# ...

# %%
#rename the Quater colummn as current Quarter
close.rename(columns = {'Quarter' : 'Cur Quarter'}, inplace = True)
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter
# 0         2014Q1
# 1         2014Q1
# 2         2014Q1
# ...

# %%
#this formula use to differentiation the previous quarter vs current quater, previous quater is a "date value" to calcuate PE ratio for current trading price, which use close price
def previous_quarter_date(val):
    if val.month < 4:
        return datetime.date(val.year - 1, 12, 31)
    elif val.month < 7:
        return datetime.date(val.year, 3, 31)
    elif val.month < 10:
        return datetime.date(val.year, 6, 30)
    return datetime.date(val.year, 9, 30)

# %%
#assign value to previous quarter
import datetime
close['pre Qdate'] = close['Date'].apply(previous_quarter_date)
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter   pre Qdate
# 0         2014Q1  2013-12-31
# ...

# %%
#adding a column as of FSQuarter for merge purpose,format to same format of Current Quarter
close['pre Qdate'] = pd.to_datetime(close['pre Qdate'])
close['FSQuarter'] = close['pre Qdate'].dt.to_period('Q')
close['year'] = close['Date'].dt.year
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter  pre Qdate FSQuarter  year
# ...

# %%
#drop the 'pre Qdate'column for data cleaning
column_to_drop = 'pre Qdate'
close.drop(columns=[column_to_drop], inplace=True)
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year
# 0         2014Q1    2013Q4  2014
# ...

# %%
#import AMZN earning report Data set from Fidelity account
amznEPS = pd.read_csv("amzn.csv")
amznEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/25/24          --                   0.68
# 1       NaN         NaN         NaN          (22 Analysts)
# 2   Q4 2023     1/31/24          --                   0.77
# 3       NaN         NaN         NaN          (36 Analysts)
# 4   Q3 2023    10/26/23          --                   0.58
# ..      ...         ...         ...                    ...
# 79      NaN         NaN         NaN          (37 Analysts)
# 80  Q1 2014     4/24/14          --                   0.23
# 81      NaN         NaN         NaN          (36 Analysts)
# 82  Q4 2013     1/30/14          --                   0.66
# 83      NaN         NaN         NaN          (39 Analysts)
#
#    Adjusted actuals EPS ($) EPS difference Est. low/high range ($)  \
# 0                        --             --             0.36 / 1.04
# 1                       NaN            NaN                     NaN
# ...

# %%
print(amznEPS.columns)
# Out:
# Index(['Quarter', 'Report date', 'Report time', 'Consensus est. EPS ($)',
#        'Adjusted actuals EPS ($)', 'EPS difference', 'Est. low/high range ($)',
#        'StarMine from Refinitiv SmartEstimate($) ', 'GAAP EPS ($)',
#        'Reported EPS ($)'],
#       dtype='object')

# %%
#add column as of FSQuarter for merge purpose
quarter_info = amznEPS['Quarter'].str.extract(r'Q(\d) (\d{4})')
amznEPS['FSQuarter'] = quarter_info[1] + 'Q' + quarter_info[0]

# %%
amznEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/25/24          --                   0.68
# 1       NaN         NaN         NaN          (22 Analysts)
# 2   Q4 2023     1/31/24          --                   0.77
# 3       NaN         NaN         NaN          (36 Analysts)
# 4   Q3 2023    10/26/23          --                   0.58
# ..      ...         ...         ...                    ...
# 79      NaN         NaN         NaN          (37 Analysts)
# 80  Q1 2014     4/24/14          --                   0.23
# 81      NaN         NaN         NaN          (36 Analysts)
# 82  Q4 2013     1/30/14          --                   0.66
# 83      NaN         NaN         NaN          (39 Analysts)
#
#    Adjusted actuals EPS ($) EPS difference Est. low/high range ($)  \
# 0                        --             --             0.36 / 1.04
# 1                       NaN            NaN                     NaN
# ...

# %%
#check datatype for merge purpose
close["FSQuarter"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2491 entries, 0 to 2490
# Series name: FSQuarter
# Non-Null Count  Dtype
# --------------  -----
# 2491 non-null   period[Q-DEC]
# dtypes: period[Q-DEC](1)
# memory usage: 19.6 KB

# %%
amznEPS["FSQuarter"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 84 entries, 0 to 83
# Series name: FSQuarter
# Non-Null Count  Dtype
# --------------  -----
# 42 non-null     object
# dtypes: object(1)
# memory usage: 804.0+ bytes

# %%
#change the merge column to the same datetype 
amznEPS['FSQuarter'] = pd.PeriodIndex(amznEPS['FSQuarter'], freq='Q-DEC')
amznEPS["FSQuarter"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 84 entries, 0 to 83
# Series name: FSQuarter
# Non-Null Count  Dtype
# --------------  -----
# 42 non-null     period[Q-DEC]
# dtypes: period[Q-DEC](1)
# memory usage: 804.0 bytes

# %%
#drop the n/a rows and adding year column 
amznEPS = amznEPS.dropna()
amznEPS['year'] = amznEPS['Quarter'].str.extract('(\d{4})').astype(int)
amznEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/3629117233.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amznEPS['year'] = amznEPS['Quarter'].str.extract('(\d{4})').astype(int)
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/25/24          --                   0.68
# 2   Q4 2023     1/31/24          --                   0.77
# 4   Q3 2023    10/26/23          --                   0.58
# 6   Q2 2023      8/3/23          --                   0.35
# 8   Q1 2023     4/27/23          --                   0.21
# 10  Q4 2022      2/2/23          --                   0.18
# 12  Q3 2022    10/27/22          --                   0.22
# ...

# %%
#change the value to number for later calculation 
#yeps value for Earning per share(calendar year, chart 1)
#4Q Sum, value for Earning per share(last four Quarterly report, PE ration, chart2)
amznEPS['Reported EPS ($)'] = pd.to_numeric(amznEPS['Reported EPS ($)'], errors='coerce')
amznEPS['amznyeps'] = amznEPS.groupby('year')['Reported EPS ($)'].transform('sum')
amznEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/1148767470.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amznEPS['Reported EPS ($)'] = pd.to_numeric(amznEPS['Reported EPS ($)'], errors='coerce')
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/1148767470.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amznEPS['amznyeps'] = amznEPS.groupby('year')['Reported EPS ($)'].transform('sum')
# ...

# %%
#to get value for all 4 previous quarterly eps as rolling annual eps
data = amznEPS["Reported EPS ($)"]
amznEPSdata = pd.DataFrame(data)
amznEPSdata['Reported EPS ($)'] = pd.to_numeric(amznEPSdata['Reported EPS ($)'], errors='coerce')
window_size = 4
rolling_sum = amznEPSdata.rolling(window=window_size).sum()
rolling_sum_shifted = rolling_sum.shift(-window_size + 1)

# %%
amznEPS['amzn4Qsum'] = rolling_sum_shifted
amznEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/1439999217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amznEPS['amzn4Qsum'] = rolling_sum_shifted
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/25/24          --                   0.68
# 2   Q4 2023     1/31/24          --                   0.77
# 4   Q3 2023    10/26/23          --                   0.58
# 6   Q2 2023      8/3/23          --                   0.35
# 8   Q1 2023     4/27/23          --                   0.21
# 10  Q4 2022      2/2/23          --                   0.18
# 12  Q3 2022    10/27/22          --                   0.22
# 14  Q2 2022     7/28/22          --                   0.14
# ...

# %%
merged_amznEPS = pd.merge(close, amznEPS, on='FSQuarter', how='inner')
merged_amznEPS
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year_x  Quarter  ... Consensus est. EPS ($)  \
# ...

# %%
#Merege the EPS to Master dataset
close["amzn4Qsum"] = merged_amznEPS['amzn4Qsum']
close["amznPEratio"] = close["AMZN"] / close["amzn4Qsum"]

# %%
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  amznPEratio
# ...

# %%
#To get the value PE Ration as financial mertic
close['amznyeps'] = merged_amznEPS['amznyeps']
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  amznPEratio  amznyeps
# ...

# %%
#repeat the above step for the rest of the companies
#import Google EPS report
bacEPS = pd.read_csv("bac.csv")
print(bacEPS.columns)
# Out:
# Index(['Quarter', 'Report date', 'Report time', 'Consensus est. EPS ($)',
#        'Adjusted actuals EPS ($)', 'EPS difference', 'Est. low/high range ($)',
#        'StarMine from Refinitiv SmartEstimate($) ', 'GAAP EPS ($)',
#        'Reported EPS ($)'],
#       dtype='object')

# %%
quarter_info = bacEPS['Quarter'].str.extract(r'Q(\d) (\d{4})')
bacEPS['FSQuarter'] = quarter_info[1] + 'Q' + quarter_info[0]
bacEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/16/24          --                   0.79
# 1       NaN         NaN         NaN          (14 Analysts)
# 2   Q4 2023  01/12/2024          --                   0.76
# 3       NaN         NaN         NaN          (16 Analysts)
# 4   Q3 2023    10/17/23          --                   0.82
# ..      ...         ...         ...                    ...
# 79      NaN         NaN         NaN          (21 Analysts)
# 80  Q1 2014     4/16/14          --                   0.05
# 81      NaN         NaN         NaN          (24 Analysts)
# 82  Q4 2013     1/15/14          --                   0.26
# 83      NaN         NaN         NaN          (29 Analysts)
#
#    Adjusted actuals EPS ($) EPS difference Est. low/high range ($)  \
# 0                        --             --             0.72 / 0.86
# 1                       NaN            NaN                     NaN
# ...

# %%
bacEPS['FSQuarter'] = pd.PeriodIndex(bacEPS['FSQuarter'], freq='Q-DEC')

# %%
bacEPS = bacEPS.dropna()
bacEPS['year'] = bacEPS['Quarter'].str.extract('(\d{4})').astype(int)
bacEPS['Reported EPS ($)'] = pd.to_numeric(bacEPS['Reported EPS ($)'], errors='coerce')
bacEPS['bacyeps'] = bacEPS.groupby('year')['Reported EPS ($)'].transform('sum')
bacEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/2228144653.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacEPS['year'] = bacEPS['Quarter'].str.extract('(\d{4})').astype(int)
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/2228144653.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacEPS['Reported EPS ($)'] = pd.to_numeric(bacEPS['Reported EPS ($)'], errors='coerce')
# ...

# %%
bacEPS['Reported EPS ($)'] = pd.to_numeric(bacEPS['Reported EPS ($)'], errors='coerce')
window_size = 4
rolling_sum = bacEPS['Reported EPS ($)'].rolling(window=window_size).sum()
rolling_sum_shifted = rolling_sum.shift(-window_size + 1)
bacEPS['bac4Qsum'] = rolling_sum_shifted
bacEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/2881757851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacEPS['Reported EPS ($)'] = pd.to_numeric(bacEPS['Reported EPS ($)'], errors='coerce')
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/2881757851.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bacEPS['bac4Qsum'] = rolling_sum_shifted
#     Quarter Report date Report time Consensus est. EPS ($)  \
# ...

# %%
merged_bacEPS = pd.merge(close, bacEPS, on='FSQuarter', how='inner')
merged_bacEPS
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year_x  amzn4Qsum  ...  Consensus est. EPS ($)  \
# ...

# %%
close["bac4Qsum"] = merged_bacEPS['bac4Qsum']
close["bacPEratio"] = close["BAC"] / close["bac4Qsum"]
close["bacyeps"] = merged_bacEPS['bacyeps']
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  amznPEratio  amznyeps  bac4Qsum  \
# ...

# %%
#import Google EPS report
googlEPS = pd.read_csv("google.csv")
print(googlEPS.columns)
# Out:
# Index(['Quarter', 'Report date', 'Report time', 'Consensus est. EPS ($)',
#        'Adjusted actuals EPS ($)', 'EPS difference', 'Est. low/high range ($)',
#        'StarMine from Refinitiv SmartEstimate($) ', 'GAAP EPS ($)',
#        'Reported EPS ($)'],
#       dtype='object')

# %%
quarter_info = googlEPS['Quarter'].str.extract(r'Q(\d) (\d{4})')
googlEPS['FSQuarter'] = quarter_info[1] + 'Q' + quarter_info[0]
googlEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/23/24          --                    1.5
# 1       NaN         NaN         NaN          (23 Analysts)
# 2   Q4 2023     1/31/24          --                   1.59
# 3       NaN         NaN         NaN          (36 Analysts)
# 4   Q3 2023    10/24/23          --                   1.45
# ..      ...         ...         ...                    ...
# 79      NaN         NaN         NaN          (42 Analysts)
# 80  Q1 2014     4/16/14          --                   6.41
# 81      NaN         NaN         NaN          (38 Analysts)
# 82  Q4 2013     1/30/14          --                    6.1
# 83      NaN         NaN         NaN          (42 Analysts)
#
#    Adjusted actuals EPS ($) EPS difference Est. low/high range ($)  \
# 0                        --             --             1.36 / 1.65
# 1                       NaN            NaN                     NaN
# ...

# %%
googlEPS['FSQuarter'] = pd.PeriodIndex(googlEPS['FSQuarter'], freq='Q-DEC')

# %%
googlEPS = googlEPS.dropna()
googlEPS['year'] = googlEPS['Quarter'].str.extract('(\d{4})').astype(int)
googlEPS['Reported EPS ($)'] = pd.to_numeric(googlEPS['Reported EPS ($)'], errors='coerce')
googlEPS['googlyeps'] = googlEPS.groupby('year')['Reported EPS ($)'].transform('sum')
googlEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/807139848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   googlEPS['year'] = googlEPS['Quarter'].str.extract('(\d{4})').astype(int)
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/807139848.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   googlEPS['Reported EPS ($)'] = pd.to_numeric(googlEPS['Reported EPS ($)'], errors='coerce')
# ...

# %%
googlEPS['Reported EPS ($)'] = pd.to_numeric(googlEPS['Reported EPS ($)'], errors='coerce')
window_size = 4
rolling_sum = googlEPS['Reported EPS ($)'].rolling(window=window_size).sum()
rolling_sum_shifted = rolling_sum.shift(-window_size + 1)
googlEPS['googl4Qsum'] = rolling_sum_shifted
googlEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/4097238381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   googlEPS['Reported EPS ($)'] = pd.to_numeric(googlEPS['Reported EPS ($)'], errors='coerce')
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/4097238381.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   googlEPS['googl4Qsum'] = rolling_sum_shifted
#     Quarter Report date Report time Consensus est. EPS ($)  \
# ...

# %%
merged_googlEPS = pd.merge(close, googlEPS, on='FSQuarter', how='inner')
merged_googlEPS
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year_x  amzn4Qsum  ...  Consensus est. EPS ($)  \
# ...

# %%
close["googl4Qsum"] = merged_googlEPS["googl4Qsum"]
close["googlPEratio"] = close["GOOGL"] / close["googl4Qsum"]
close['googlyeps'] = merged_googlEPS['googlyeps']
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  amznPEratio  amznyeps  bac4Qsum  \
# ...

# %%
#import Mcdonald's EPS report
mcdEPS = pd.read_csv("mcd.csv")
print(mcdEPS.columns)
# Out:
# Index(['Quarter', 'Report date', 'Report time', 'Consensus est. EPS ($)',
#        'Adjusted actuals EPS ($)', 'EPS difference', 'Est. low/high range ($)',
#        'StarMine from Refinitiv SmartEstimate($) ', 'GAAP EPS ($)',
#        'Reported EPS ($)'],
#       dtype='object')

# %%
quarter_info = mcdEPS['Quarter'].str.extract(r'Q(\d) (\d{4})')
mcdEPS['FSQuarter'] = quarter_info[1] + 'Q' + quarter_info[0]
mcdEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/23/24          --                   2.77
# 1       NaN         NaN         NaN          (24 Analysts)
# 2   Q4 2023     1/29/24          --                   2.81
# 3       NaN         NaN         NaN          (29 Analysts)
# 4   Q3 2023    10/30/23          --                      3
# ..      ...         ...         ...                    ...
# 79      NaN         NaN         NaN          (25 Analysts)
# 80  Q1 2014     4/22/14          --                   1.24
# 81      NaN         NaN         NaN          (24 Analysts)
# 82  Q4 2013     1/23/14          --                   1.39
# 83      NaN         NaN         NaN          (28 Analysts)
#
#    Adjusted actuals EPS ($) EPS difference Est. low/high range ($)  \
# 0                        --             --             2.65 / 2.86
# 1                       NaN            NaN                     NaN
# ...

# %%
mcdEPS['FSQuarter'] = pd.PeriodIndex(mcdEPS['FSQuarter'], freq='Q-DEC')

# %%
mcdEPS = mcdEPS.dropna()
mcdEPS['year'] = mcdEPS['Quarter'].str.extract('(\d{4})').astype(int)
mcdEPS['Reported EPS ($)'] = pd.to_numeric(mcdEPS['Reported EPS ($)'], errors='coerce')
mcdEPS['mcdyeps'] = mcdEPS.groupby('year')['Reported EPS ($)'].transform('sum')
mcdEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/1129465766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mcdEPS['year'] = mcdEPS['Quarter'].str.extract('(\d{4})').astype(int)
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/1129465766.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mcdEPS['Reported EPS ($)'] = pd.to_numeric(mcdEPS['Reported EPS ($)'], errors='coerce')
# ...

# %%
mcdEPS['Reported EPS ($)'] = pd.to_numeric(mcdEPS['Reported EPS ($)'], errors='coerce')
window_size = 4
rolling_sum = mcdEPS['Reported EPS ($)'].rolling(window=window_size).sum()
rolling_sum_shifted = rolling_sum.shift(-window_size + 1)
mcdEPS['mcd4Qsum'] = rolling_sum_shifted
mcdEPS
# Out:
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/734810753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mcdEPS['Reported EPS ($)'] = pd.to_numeric(mcdEPS['Reported EPS ($)'], errors='coerce')
# /var/folders/y_/xzdtpw157lxfxq97fg75kg4m0000gn/T/ipykernel_29991/734810753.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mcdEPS['mcd4Qsum'] = rolling_sum_shifted
#     Quarter Report date Report time Consensus est. EPS ($)  \
# ...

# %%
merged_mcdEPS = pd.merge(close, mcdEPS, on='FSQuarter', how='inner')
merged_mcdEPS
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year_x  amzn4Qsum  ...  Consensus est. EPS ($)  \
# ...

# %%
close["mcd4Qsum"] = merged_mcdEPS['mcd4Qsum']
close["mcdPEratio"] = close["MCD"] / close["mcd4Qsum"]
close['mcdyeps'] = merged_mcdEPS['mcdyeps']
close.tail()
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  ...  amznyeps  bac4Qsum  \
# 2486      2023Q4    2023Q3  2023       1.93  ...       1.9      3.57
# 2487      2023Q4    2023Q3  2023       1.93  ...       1.9      3.57
# 2488      2023Q4    2023Q3  2023       1.93  ...       1.9      3.57
# 2489      2023Q4    2023Q3  2023       1.93  ...       1.9      3.57
# 2490      2023Q4    2023Q3  2023       1.93  ...       1.9      3.57
#
#       bacPEratio  bacyeps  googl4Qsum  googlPEratio  googlyeps  mcd4Qsum  \
# ...

# %%
#Import Verizon Communications Inc EPS report
vzEPS = pd.read_csv("vz.csv")
print(vzEPS.columns)
# Out:
# Index(['Quarter', 'Report date', 'Report time', 'Consensus est. EPS ($)',
#        'Adjusted actuals EPS ($)', 'EPS difference', 'Est. low/high range ($)',
#        'StarMine from Refinitiv SmartEstimate($) ', 'GAAP EPS ($)',
#        'Reported EPS ($)'],
#       dtype='object')

# %%
quarter_info = vzEPS['Quarter'].str.extract(r'Q(\d) (\d{4})')
vzEPS['Prev Quarter'] = quarter_info[1] + 'Q' + quarter_info[0]
vzEPS['FSQuarter'] = pd.PeriodIndex(vzEPS['Prev Quarter'], freq='Q-DEC')

# %%
vzEPS = vzEPS.dropna()
vzEPS['year'] = vzEPS['Quarter'].str.extract('(\d{4})').astype(int)
vzEPS['Reported EPS ($)'] = pd.to_numeric(vzEPS['Reported EPS ($)'], errors='coerce')
vzEPS['vzyeps'] = vzEPS.groupby('year')['Reported EPS ($)'].transform('sum')

# %%
vzEPS['Reported EPS ($)'] = pd.to_numeric(vzEPS['Reported EPS ($)'], errors='coerce')
window_size = 4
rolling_sum = vzEPS['Reported EPS ($)'].rolling(window=window_size).sum()
rolling_sum_shifted = rolling_sum.shift(-window_size + 1)
vzEPS['vz4Qsum'] = rolling_sum_shifted
vzEPS
# Out:
#     Quarter Report date Report time Consensus est. EPS ($)  \
# 0   Q1 2024     4/22/24          --                   1.14
# 2   Q4 2023     1/23/24          --                   1.08
# 4   Q3 2023    10/24/23          --                   1.18
# 6   Q2 2023     7/25/23          --                   1.17
# 8   Q1 2023     4/25/23          --                    1.2
# 10  Q4 2022     1/24/23          --                   1.19
# 12  Q3 2022    10/21/22          --                   1.29
# 14  Q2 2022     7/22/22          --                   1.32
# 16  Q1 2022     4/22/22          --                   1.35
# 18  Q4 2021     1/25/22          --                   1.28
# 20  Q3 2021    10/20/21          --                   1.36
# 22  Q2 2021     7/21/21          --                    1.3
# 24  Q1 2021     4/21/21          --                   1.29
# 26  Q4 2020     1/26/21          --                   1.17
# 28  Q3 2020    10/21/20          --                   1.22
# ...

# %%
merged_vzEPS = pd.merge(close, vzEPS, on='FSQuarter', how='inner')
merged_vzEPS
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year_x  amzn4Qsum  ...  Adjusted actuals EPS ($)  \
# ...

# %%
close["vz4Qsum"] = merged_vzEPS['vz4Qsum']
close["vzPEratio"] = close["VZ"] / close["vz4Qsum"]
close['vzyeps'] = merged_vzEPS['vzyeps']
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 0    2014-01-02   19.898500  16.100000   27.855856   96.410004  49.000000
# 1    2014-01-03   19.822001  16.410000   27.652653   96.540001  48.419998
# 2    2014-01-06   19.681499  16.660000   27.960960   95.849998  48.689999
# 3    2014-01-07   19.901501  16.500000   28.500000   96.379997  49.299999
# 4    2014-01-08   20.096001  16.580000   28.559309   95.410004  48.500000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  ...  bacyeps  googl4Qsum  \
# ...

# %%
#Drop the N/A value from dataset
close= close.dropna()
close
# Out:
#            Date        AMZN        BAC       GOOGL         MCD         VZ  \
# 188  2014-10-01   15.873000  16.820000   28.981501   94.190002  49.430000
# 189  2014-10-02   15.920500  16.879999   29.044001   94.120003  49.290001
# 190  2014-10-03   16.136999  17.290001   29.312500   94.860001  49.709999
# 191  2014-10-06   16.110001  17.290001   29.389000   93.839996  50.080002
# 192  2014-10-07   15.849000  16.879999   28.705000   92.809998  49.680000
# ...         ...         ...        ...         ...         ...        ...
# 2486 2023-11-16  142.830002  29.540001  136.929993  276.119995  36.180000
# 2487 2023-11-17  145.179993  29.980000  135.309998  275.750000  36.230000
# 2488 2023-11-20  146.130005  30.010000  136.250000  279.029999  36.730000
# 2489 2023-11-21  143.899994  29.660000  136.970001  280.470001  37.250000
# 2490 2023-11-22  146.710007  29.629999  138.490005  281.929993  37.349998
#
#      Cur Quarter FSQuarter  year  amzn4Qsum  ...  bacyeps  googl4Qsum  \
# ...

# %%
close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2303 entries, 188 to 2490
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2303 non-null   datetime64[ns]
#  1   AMZN          2303 non-null   float64
#  2   BAC           2303 non-null   float64
#  3   GOOGL         2303 non-null   float64
#  4   MCD           2303 non-null   float64
#  5   VZ            2303 non-null   float64
#  6   Cur Quarter   2303 non-null   period[Q-DEC]
#  7   FSQuarter     2303 non-null   period[Q-DEC]
#  8   year          2303 non-null   int64
#  9   amzn4Qsum     2303 non-null   float64
#  10  amznPEratio   2303 non-null   float64
#  11  amznyeps      2303 non-null   float64
#  12  bac4Qsum      2303 non-null   float64
#  13  bacPEratio    2303 non-null   float64
#  14  bacyeps       2303 non-null   float64
#  15  googl4Qsum    2303 non-null   float64
#  16  googlPEratio  2303 non-null   float64
# ...

# %%
#export the final dataset 
close.to_csv('fivecompanydata.csv', index=False)

# %%
close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2303 entries, 188 to 2490
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2303 non-null   datetime64[ns]
#  1   AMZN          2303 non-null   float64
#  2   BAC           2303 non-null   float64
#  3   GOOGL         2303 non-null   float64
#  4   MCD           2303 non-null   float64
#  5   VZ            2303 non-null   float64
#  6   Cur Quarter   2303 non-null   period[Q-DEC]
#  7   FSQuarter     2303 non-null   period[Q-DEC]
#  8   year          2303 non-null   int64
#  9   amzn4Qsum     2303 non-null   float64
#  10  amznPEratio   2303 non-null   float64
#  11  amznyeps      2303 non-null   float64
#  12  bac4Qsum      2303 non-null   float64
#  13  bacPEratio    2303 non-null   float64
#  14  bacyeps       2303 non-null   float64
#  15  googl4Qsum    2303 non-null   float64
#  16  googlPEratio  2303 non-null   float64
# ...

# %%
#Schema

# %% [markdown]
# CREATE TABLE ftp3(
#     Date DATE NOT NULL,
#     AMZN NUMERIC(10,2) NOT NULL,
#     BAC NUMERIC(10,2) NOT NULL,
#     GOOGL NUMERIC(10,2) NOT NULL,
#     MCD NUMERIC(10,2) NOT NULL,
#     VZ NUMERIC(10,2) NOT NULL,
#     CurQuarter TEXT NOT NULL,
#     FSQuarter TEXT NOT NULL,
#     year INT NOT NULL,
#     amzn4Qsum NUMERIC(10,2) NOT NULL,
#     amznPE NUMERIC(10,2) NOT NULL,
#     amznyeps NUMERIC(10,2) NOT NULL,
#     bac4Qsum NUMERIC(10,2) NOT NULL,
#     bacPEratio NUMERIC(10,2) NOT NULL,
#     bacyeps NUMERIC(10,2) NOT NULL,
#     googl4Qsum NUMERIC(10,2) NOT NULL,
#     googlPEratio NUMERIC(10,2) NOT NULL,
#     googlyeps NUMERIC(10,2) NOT NULL,
#     mcd4Qsum NUMERIC(10,2) NOT NULL,
#     mcdPEratio NUMERIC(10,2) NOT NULL,
#     mcdyeps NUMERIC(10,2) NOT NULL,
#     vz4Qsum NUMERIC(10,2) NOT NULL,
#     vzPEratio NUMERIC(10,2) NOT NULL,
#     vzyeps NUMERIC(10,2) NOT NULL
# );

# %%
# !pip install psycopg2

# %%
from sqlalchemy import create_engine

from config import username, password, hostname, port, db

engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{hostname}:{port}/{db}')

# %%
close.to_sql("ftp3", con=engine, if_exists="replace", index=False)

# %%
from sqlalchemy import text
with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM ftp3"))
    print(list(result))
